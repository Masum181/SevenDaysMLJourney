# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("./data/sample_survey_results_public.csv")
df_schema = pd.read_csv("./data/survey_results_schema.csv")

# %%
country_group = df.groupby("Country")

# %%
df["Country"]
# Out:
# 0                    Brazil
# 1        Dominican Republic
# 2             United States
# 3                    Brazil
# 4                     India
#                 ...
# 16110               Finland
# 16111                 India
# 16112                 India
# 16113               Germany
# 16114         United States
# Name: Country, Length: 16115, dtype: object

# %%
country_group.get_group("Brazil")
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0           63311                     I am a developer by profession      Yes
# 3           42192                     I am a developer by profession      Yes
# 48          38607                     I am a developer by profession       No
# 61          60336             I am a student who is learning to code      Yes
# 158         23304                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 16033       39809                     I am a developer by profession       No
# 16039       33028                     I am a developer by profession      Yes
# 16081       33136                     I am a developer by profession      Yes
# 16092       58730  I used to be a developer by profession, but no...      Yes
# 16107       57397             I am a student who is learning to code      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp Country  \
# 0      27.0         16  Monthly    40000.0       109956.0  Brazil
# 3       NaN         15      NaN        NaN            NaN  Brazil
# 48      NaN         15  Monthly     5000.0        13740.0  Brazil
# 61     22.0         18      NaN        NaN            NaN  Brazil
# 158    32.0         16  Monthly     6500.0        17868.0  Brazil
# ...     ...        ...      ...        ...            ...     ...
# 16033   NaN        NaN      NaN        NaN            NaN  Brazil
# 16039  32.0         20  Monthly     6500.0        17868.0  Brazil
# 16081  25.0         17  Monthly     6000.0        16488.0  Brazil
# 16092  50.0         20      NaN        NaN            NaN  Brazil
# 16107   NaN         18      NaN        NaN            NaN  Brazil
#
#          CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0      Brazilian real  ...  Neither easy nor difficult  Appropriate in length
# 3                 NaN  ...                         NaN                    NaN
# 48     Brazilian real  ...                         NaN                    NaN
# 61                NaN  ...                        Easy  Appropriate in length
# 158    Brazilian real  ...  Neither easy nor difficult  Appropriate in length
# ...               ...  ...                         ...                    ...
# 16033             NaN  ...                         NaN                    NaN
# 16039  Brazilian real  ...                        Easy  Appropriate in length
# 16081  Brazilian real  ...                        Easy  Appropriate in length
# 16092             NaN  ...                        Easy               Too long
# 16107             NaN  ...  Neither easy nor difficult               Too long
#
#       Trans                                     UndergradMajor  \
# 0        No  Computer science, computer engineering, or sof...
# 3       NaN  Computer science, computer engineering, or sof...
# 48      NaN  Information systems, information technology, o...
# 61       No                                                NaN
# 158      No  Computer science, computer engineering, or sof...
# ...     ...                                                ...
# 16033   NaN                                                NaN
# 16039    No  Computer science, computer engineering, or sof...
# 16081    No  Another engineering discipline (such as civil,...
# 16092    No  Computer science, computer engineering, or sof...
# 16107    No  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                  WebframeWorkedWith  \
# 0      Angular;ASP.NET Core;Vue.js                Angular;ASP.NET Core
# 3                              NaN                                 NaN
# 48                             NaN                                 NaN
# 61                             NaN                    Express;React.js
# 158           Angular;ASP.NET Core         ASP.NET;ASP.NET Core;jQuery
# ...                            ...                                 ...
# 16033                          NaN                                 NaN
# 16039         Angular;ASP.NET Core                Angular;ASP.NET Core
# 16081             Express;React.js  Angular.js;Express;jQuery;React.js
# 16092      Angular;React.js;Spring                                 NaN
# 16107                          NaN       Angular;Django;Flask;React.js
#
#                                   WelcomeChange WorkWeekHrs YearsCode  \
# 0       Just as welcome now as I felt last year        80.0         8
# 3       Just as welcome now as I felt last year         NaN         5
# 48                                          NaN        42.0        15
# 61      Just as welcome now as I felt last year         NaN         4
# 158    Somewhat more welcome now than last year         8.0        16
# ...                                         ...         ...       ...
# 16033                                       NaN         NaN       NaN
# 16039  Somewhat less welcome now than last year        40.0        12
# 16081     A lot more welcome now than last year        40.0         8
# 16092   Just as welcome now as I felt last year         NaN         7
# 16107                                       NaN         NaN        22
#
#            YearsCodePro
# 0                     7
# 3      Less than 1 year
# 48                   10
# 61                  NaN
# 158                  11
# ...                 ...
# 16033               NaN
# 16039                12
# 16081                 3
# 16092                 5
# 16107               NaN
#
# [466 rows x 61 columns]

# %%
country_usg_python = country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
