# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("project_output.csv")

# %%
df.head()
# Out:
#        Unnamed: 0  NumRespondent  KnowsPython  knowsJavaScript  KnowsJava  \
# 0   United States           3120         1505             2001       2279
# 1           India           2112          680             1112       1420
# 2         Germany            977          417              574        701
# 3  United Kingdom            971          394              609        677
# 4          Canada            562          267              365        422
#
#    ProgrammingAsHobby  NumStudent  AverageAge  AverageAnnualSalary(USD)  \
# 0              2455.0         266   33.841015             208302.030479
# 1              1681.0         339   25.874013              25904.796270
# 2               814.0         143   31.320530              87346.336879
# 3               754.0          76   33.819389             152917.248476
# 4               437.0          80   31.534606             102923.195195
#
#    AverageWorkingWeekHours
# 0                41.924109
# 1                39.804195
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'NumRespondent', 'KnowsPython', 'knowsJavaScript',
#        'KnowsJava', 'ProgrammingAsHobby', 'NumStudent', 'AverageAge',
#        'AverageAnnualSalary(USD)', 'AverageWorkingWeekHours'],
#       dtype='object')

# %%
df.rename(columns={"Unnamed: 0": "Country"}, inplace=True)

# %%
df
# Out:
#             Country  NumRespondent  KnowsPython  knowsJavaScript  KnowsJava  \
# 0     United States           3120         1505             2001       2279
# 1             India           2112          680             1112       1420
# 2           Germany            977          417              574        701
# 3    United Kingdom            971          394              609        677
# 4            Canada            562          267              365        422
# ..              ...            ...          ...              ...        ...
# 160    Burkina Faso              1            1                0          0
# 161       Swaziland              1            1                0          1
# 162      San Marino              1            0                1          1
# 163           Haiti              1            0                0          0
# 164          Belize              1            1                1          1
#
# ...

# %%
df[["NumRespondent", "Country"]][:10].plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.sort_values(by=["NumRespondent", "KnowsPython"], ascending=False, inplace=True)

# %%
df[:10]
# Out:
#           Country  NumRespondent  KnowsPython  knowsJavaScript  KnowsJava  \
# 0   United States           3120         1505             2001       2279
# 1           India           2112          680             1112       1420
# 2         Germany            977          417              574        701
# 3  United Kingdom            971          394              609        677
# 4          Canada            562          267              365        422
# 5          France            472          211              299        350
# 6          Brazil            466          168              305        341
# 7     Netherlands            353          149              229        264
# 8       Australia            321          142              216        238
# 9          Poland            300          130              167        223
#
#    ProgrammingAsHobby  NumStudent  AverageAge  AverageAnnualSalary(USD)  \
# 0              2455.0         266   33.841015             208302.030479
# ...

# %%
df.loc[0:10, "Country"]
# Out:
# 0      United States
# 1              India
# 2            Germany
# 3     United Kingdom
# 4             Canada
# 5             France
# 6             Brazil
# 7        Netherlands
# 8          Australia
# 9             Poland
# 10             Italy
# Name: Country, dtype: object

# %%
plt.barh(df.loc[:10, "Country"],df.loc[:10, "KnowsPython"])
plt.xlabel("Knows Python")
plt.ylabel("Country")

plt.show()

# %%
df["Country"][:10]
# Out:
# C:\Users\MASUM\AppData\Local\Temp\ipykernel_22264\1741242635.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df["Country"][:10]
# 0     United States
# 1             India
# 2           Germany
# 3    United Kingdom
# 4            Canada
# 5            France
# 6            Brazil
# 7       Netherlands
# 8         Australia
# 9            Poland
# Name: Country, dtype: object

# %%
df.loc[:10].sort_values(by="KnowsPython").loc[:, 'KnowsPython']
# Out:
# 10     102
# 9      130
# 8      142
# 7      149
# 6      168
# 5      211
# 4      267
# 3      394
# 2      417
# 1      680
# 0     1505
# Name: KnowsPython, dtype: int64

# %%
x = df.loc[:10].sort_values(by="KnowsPython").loc[:, "Country"]
y= df.loc[:10].sort_values(by="KnowsPython").loc[:, "KnowsPython"]
plt.barh(x,y)
plt.xlabel("Knows python")
plt.ylabel("Country")
plt.show()

# %%
x = df.loc[:10].sort_values(by="KnowsPython").loc[:, "Country"]
y= df.loc[:10].sort_values(by="KnowsPython").loc[:, "KnowsPython"]
plt.bar(x,y)
plt.xlabel("Country")
plt.ylabel("Knows python")
plt.show()

# %%
plt.figure(figsize=(12,8))
x = df.loc[:10].sort_values(by="KnowsPython").loc[:, "Country"]
y= df.loc[:10].sort_values(by="KnowsPython").loc[:, "KnowsPython"]
plt.bar(x,y)
plt.xlabel("Country")
plt.ylabel("Knows python")
plt.show()

# %%
df.loc[1:10, ["NumRespondent", "KnowsPython", "knowsJavaScript", "KnowsJava"]].plot(kind='line')
plt.grid()

# %%
x = df.loc[:10, "Country"]
y = df.loc[:10, ["KnowsPython", "knowsJavaScript", "KnowsJava"]]
plt.plot(x,y)
plt.xlabel("Number of Respondent")
plt.ylabel("Knwos Programming")
plt.legend(["KnowsPython", "knowsJavaScript", "KnowsJava"])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,12))
x = df.loc[:10, "Country"]
y = df.loc[:10, ["KnowsPython", "knowsJavaScript", "KnowsJava"]]
plt.plot(x,y)
plt.xlabel("Number of Respondent")
plt.ylabel("Knwos Programming")
plt.legend(["KnowsPython", "knowsJavaScript", "KnowsJava"])
plt.tight_layout()
plt.show()

# %%
df.loc[:10, ["KnowsPython", "knowsJavaScript", "KnowsJava"]].plot.bar();

# %%
df.loc[:10, ["Country","KnowsPython", "knowsJavaScript", "KnowsJava"]].set_index("Country").plot.bar();

# %%
import seaborn as sns

# %%
df.loc[:10, ["Country", "NumRespondent", "KnowsPython"]]
# Out:
#            Country  NumRespondent  KnowsPython
# 0    United States           3120         1505
# 1            India           2112          680
# 2          Germany            977          417
# 3   United Kingdom            971          394
# 4           Canada            562          267
# 5           France            472          211
# 6           Brazil            466          168
# 7      Netherlands            353          149
# 8        Australia            321          142
# 9           Poland            300          130
# 10           Italy            299          102

# %%
plt.figure(figsize=(12,12))
sns.lineplot(data=df[:10], x="Country", y="NumRespondent")
sns.scatterplot(data=df[:10], x="Country", y="NumRespondent")
plt.show()

# %%
sns.scatterplot(data=df[:10], x=df.loc[:10, "Country"], y=df.loc[:10, "NumRespondent"], hue="KnowsPython")
plt.show()

# %%
df.head()
# Out:
#           Country  NumRespondent  KnowsPython  knowsJavaScript  KnowsJava  \
# 0   United States           3120         1505             2001       2279
# 1           India           2112          680             1112       1420
# 2         Germany            977          417              574        701
# 3  United Kingdom            971          394              609        677
# 4          Canada            562          267              365        422
#
#    ProgrammingAsHobby  NumStudent  AverageAge  AverageAnnualSalary(USD)  \
# 0              2455.0         266   33.841015             208302.030479
# 1              1681.0         339   25.874013              25904.796270
# 2               814.0         143   31.320530              87346.336879
# 3               754.0          76   33.819389             152917.248476
# 4               437.0          80   31.534606             102923.195195
#
#    AverageWorkingWeekHours
# 0                41.924109
# 1                39.804195
# ...

# %%
plt.figure(figsize=(12,12))
sns.lineplot(x='Country', y='KnowsPython', data=df[:10])
# Out:
# <AxesSubplot: xlabel='Country', ylabel='KnowsPython'>

# %%
plt.figure(figsize=(12,12))
sns.barplot(x='Country', y='KnowsPython', data=df[:10])
# Out:
# <AxesSubplot: xlabel='Country', ylabel='KnowsPython'>

# %%
plt.figure(figsize=(12,12))
sns.barplot(x='Country', y='KnowsPython', data=df[:10])
sns.lineplot(x='Country', y='KnowsPython', data=df[:10])
# Out:
# <AxesSubplot: xlabel='Country', ylabel='KnowsPython'>

# %%
df.head()
# Out:
#           Country  NumRespondent  KnowsPython  knowsJavaScript  KnowsJava  \
# 0   United States           3120         1505             2001       2279
# 1           India           2112          680             1112       1420
# 2         Germany            977          417              574        701
# 3  United Kingdom            971          394              609        677
# 4          Canada            562          267              365        422
#
#    ProgrammingAsHobby  NumStudent  AverageAge  AverageAnnualSalary(USD)  \
# 0              2455.0         266   33.841015             208302.030479
# 1              1681.0         339   25.874013              25904.796270
# 2               814.0         143   31.320530              87346.336879
# 3               754.0          76   33.819389             152917.248476
# 4               437.0          80   31.534606             102923.195195
#
#    AverageWorkingWeekHours
# 0                41.924109
# 1                39.804195
# ...

# %%
sns.pairplot(df.loc[:10], hue="KnowsPython")

# %%
plt.figure(figsize=(12,15))
for i in range(1, 9):
    ax = plt.subplot(3,3,i)
    plt.scatter(x= df[df.columns[0]], y=df[df.columns[i+1]])
    plt.xlabel("Country")
    plt.ylabel(df.columns[i+1])
#     plt.axis("off")
plt.show()

# %%
df
# Out:
#             Country  NumRespondent  KnowsPython  knowsJavaScript  KnowsJava  \
# 0     United States           3120         1505             2001       2279
# 1             India           2112          680             1112       1420
# 2           Germany            977          417              574        701
# 3    United Kingdom            971          394              609        677
# 4            Canada            562          267              365        422
# ..              ...            ...          ...              ...        ...
# 156    Turkmenistan              1            0                0          0
# 157          Guinea              1            0                1          1
# 158         Burundi              1            0                0          0
# 162      San Marino              1            0                1          1
# 163           Haiti              1            0                0          0
#
# ...

# %%
df.columns[9]
# Out:
# 'AverageWorkingWeekHours'
